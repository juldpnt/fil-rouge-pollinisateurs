# %% [markdown]
# # Introduction

# %% [markdown]
# Dans ce notebook, on utilise le jeu de données issus de l'augmentation de données (ajout de taxons, API Plantnet...) afin de rechercher à nouveaux des motifs fréquents et potentielles règles d'associations intéressantes plantes-insectes.
#
# Précédemment, nous avions recherché des motifs fréquents et règles d'associations importantes (lift supérieur à 1) plantes-insectes à partir des taxons présents dans la base du SPIPOLL : taxons _sc, _fr, _precision.
#
# Pour un seuil de support minimal de 0.5, la recherche n'avait pas permis de mettre en évidence des motifs fréquents intéressants et règles d'associations importantes. L'abaissement du seuil à 0.4 avait permis de mettre en lumière un motif frelon-lierre, sans toutefois soulever une règle d'association importante.
#
# On se demande si d'autres motifs fréquents intéressants n'apparaitraient pas à un niveau de granularité plus global, grâce à l'approfondissement de la taxonomie. On va donc tester ici les niveaux de taxonomie suivant :
# - plante_famille, plante_genre, plante_espece
# - insecte_ordre, insecte_super_famille, insecte_famille, insecte_sous_famille, insecte_genre, insecte_espece.
#
#
# Dans le notebook précédent, nous avons testé pour la taxonomie la plus générale : plante_famille et insecte_ordre. Aucune conclusion biologiquement intéressante.

# %% [markdown]
# # Chargement des données

# %%
import pandas as pd

# %% [markdown]
# Décommentez la cellule suivante si vous avez besoin d'installer la librairie qui nous servira à la recherche de motifs fréquents.

# %%
# Installation de la librairie permettant la recherche de motifs fréquents 
#! pip install mlxtend

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_csv("./spipoll.csv")
# Out:
# C:\Users\guilts0300\AppData\Local\Temp\ipykernel_23024\35506862.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./spipoll.csv")

# %%
unused_columns = ['collection_nom', 'collection_id', 'protocole_long', 'user_id',
       'photo_fleur', 'photo_plante', 'photo_feuille',               
       'plante_caractere', 'plante_inconnue',
       'photo_fleur', 'photo_plante', 'photo_feuille', 'coordonnees_GPS',
       'code_postal', 'fleur_ombre', 
       'insecte_abondance', 'insecte_commentaire', 'insecte_vu_sur_fleur',
       'nb_validation', 'nb_suggestion']

# %%
df.drop(columns=unused_columns, inplace=True)

# %%
# Transformation de la variable habitat

# One hot encoding après création de nouvelles colonnes pour chacun des habitats spécifiés entre ','
habitat_dummies = df['habitat'].str.get_dummies(',')

# Concaténation les colonnes de dummies avec le DataFrame d'origine
df = pd.concat([df, habitat_dummies], axis=1)

# %%
df.drop(columns=['habitat'], inplace=True)

# %%
df.columns
# Out:
# Index(['plante_famille', 'plante_genre', 'plante_espece', 'plante_sc',
#        'plante_fr', 'plante_precision', 'grande_culture', 'collection_date',
#        'collection_heure_debut', 'nebulosite', 'temperature', 'vent',
#        'insecte_ordre', 'insecte_super_famille', 'insecte_famille',
#        'insecte_sous_famille', 'insecte_genre', 'insecte_espece', 'insecte_sc',
#        'insecte_fr', 'insecte_denominationPlusPrecise', 'insecte_CdNomtaxref',
#        'bord de l'eau', 'bord de route', 'forêt', 'grande(s) culture(s)',
#        'jardin privé', 'littoral', 'parc ou jardin public', 'prairie',
#        'péri-urbain', 'rochers', 'rural', 'urbain'],
#       dtype='object')

# %% [markdown]
# # Recherche de motifs fréquents

# %%
df['insecte_genre'].nunique()
# Out:
# 333

# %%
df['insecte_genre'].value_counts()
# Out:
# Bombus          37429
# Apis            30174
# Lasioglossum    27995
# Eristalis       22124
# Calliphora      16863
#                 ...
# Setina              1
# Danaus              1
# Amata               1
# Lepturobosca        1
# Pseudoips           1
# Name: insecte_genre, Length: 333, dtype: int64

# %%
df['plante_genre'].nunique()
# Out:
# 871

# %%
df['plante_genre'].value_counts()
# Out:
# Heracleum        34343
# Hedera           19843
# Calendula        18789
# Achillea         17881
# Mentha           15167
#                  ...
# Glycyrrhiza          1
# Muehlenbeckia        1
# Stipa                1
# Lolium               1
# Cupressus            1
# Name: plante_genre, Length: 871, dtype: int64

# %% [markdown]
# Dans ce notebook, on utilise le jeu de données issus de l'augmentation de données (ajout de taxons, API Plantnet...) afin de rechercher à nouveaux des motifs fréquents et potentielles règles d'associations intéressantes plantes-insectes.
#
# Précédemment, nous avions recherché des motifs fréquents et règles d'associations importantes (lift supérieur à 1) plantes-insectes à partir des taxons présents dans la base du SPIPOLL : taxons _sc, _fr, _precision.
#
# Pour un seuil de support minimal de 0.5, la recherche n'avait pas permis de mettre en évidence des motifs fréquents intéressants et règles d'associations importantes. L'abaissement du seuil à 0.4 avait permis de mettre en lumière un motif frelon-lierre, sans toutefois soulever une règle d'association importante.
#
# On se demande si d'autres motifs fréquents intéressants n'apparaitraient pas à un niveau de granularité plus global, grâce à l'approfondissement de la taxonomie. On va donc tester ici les niveaux de taxonomie suivant :
# - plante_famille, plante_genre, plante_espece
# - insecte_ordre, insecte_super_famille, insecte_famille, insecte_sous_famille, insecte_genre, insecte_espece.

# %% [markdown]
# ## Vérification sur un exemple courant

# %% [markdown]
# On teste ici sur l'ordre incluant les bourdons, abeilles, frelons, etc. On aimerait trouver des motifs fréquents avec une famille de plantes.

# %%
data=df.where(df['insecte_genre']=='Bombus').dropna(subset=['insecte_genre'])

# %%
data.columns
# Out:
# Index(['plante_famille', 'plante_genre', 'plante_espece', 'plante_sc',
#        'plante_fr', 'plante_precision', 'grande_culture', 'collection_date',
#        'collection_heure_debut', 'nebulosite', 'temperature', 'vent',
#        'insecte_ordre', 'insecte_super_famille', 'insecte_famille',
#        'insecte_sous_famille', 'insecte_genre', 'insecte_espece', 'insecte_sc',
#        'insecte_fr', 'insecte_denominationPlusPrecise', 'insecte_CdNomtaxref',
#        'bord de l'eau', 'bord de route', 'forêt', 'grande(s) culture(s)',
#        'jardin privé', 'littoral', 'parc ou jardin public', 'prairie',
#        'péri-urbain', 'rochers', 'rural', 'urbain'],
#       dtype='object')

# %%
to_drop = ['plante_famille', 'plante_espece', 'plante_sc',
       'plante_fr', 'plante_precision', 'grande_culture',
       'collection_date', 'collection_heure_debut', 
        'insecte_super_famille',
       'insecte_famille', 'insecte_sous_famille', 'insecte_ordre',
       'insecte_espece', 'insecte_sc', 'insecte_fr',
       'insecte_denominationPlusPrecise', 'insecte_CdNomtaxref']

# %%
data.drop(columns=to_drop, inplace=True)

# %%
data.columns
# Out:
# Index(['plante_genre', 'nebulosite', 'temperature', 'vent', 'insecte_genre',
#        'bord de l'eau', 'bord de route', 'forêt', 'grande(s) culture(s)',
#        'jardin privé', 'littoral', 'parc ou jardin public', 'prairie',
#        'péri-urbain', 'rochers', 'rural', 'urbain'],
#       dtype='object')

# %%
# One hot encoding
df_encoded = pd.get_dummies(data)
df_encoded = df_encoded.astype(bool)

# %%
# Recherche des motifs fréquents
frequent_itemsets = apriori(df_encoded, min_support=0.5, use_colnames=True)

# Filtrage des motifs fréquents de taille minimale égale à 2
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets = frequent_itemsets[frequent_itemsets['length'] >= 2].drop(columns='length')

# Classement par ordre décroissant de support 
frequent_itemsets = frequent_itemsets.sort_values(by='support', ascending=False)
frequent_itemsets
# Out:
#     support                                     itemsets
# 3  0.814769     (nebulosite_0-25%, insecte_genre_Bombus)
# 4  0.601539  (temperature_20-30ºC, insecte_genre_Bombus)

# %%
frequent_itemsets['itemsets'].unique()
# Out:
# array([frozenset({'nebulosite_0-25%', 'insecte_genre_Bombus'}),
#        frozenset({'temperature_20-30ºC', 'insecte_genre_Bombus'})],
#       dtype=object)

# %% [markdown]
# ## Sur toute la base

# %%
# Suppression des lignes dont la valeur est manquante dans la colonne insecte_genre
df.dropna(subset=['insecte_genre'], inplace=True)

# %%
# Vérification
df['insecte_genre'].isnull().sum()
# Out:
# 0

# %%
for insect in df['insecte_genre'].unique().tolist() :

    data=df.where(df['insecte_genre']==insect).dropna(subset=['insecte_genre'])
    
    #Nettoyage des colonnes inutiles (on ne garde que plante_famille pour les taxons de plantes)
    to_drop= ['plante_famille', 'plante_espece', 'plante_sc',
       'plante_fr', 'plante_precision', 'grande_culture',
       'collection_date', 'collection_heure_debut', 
        'insecte_super_famille',
       'insecte_famille', 'insecte_sous_famille', 'insecte_ordre',
       'insecte_espece', 'insecte_sc', 'insecte_fr',
       'insecte_denominationPlusPrecise', 'insecte_CdNomtaxref']
    data.drop(columns=to_drop, inplace=True)
    
    # One hot encoding
    df_encoded = pd.get_dummies(data)
    df_encoded = df_encoded.astype(bool)
    
    # Algo a priori sur le jeu encodé
    frequent_itemsets = apriori(df_encoded, min_support=0.3, use_colnames=True)

    # Filtrer les motifs fréquents pour une taille minimale de 2
    frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
    frequent_itemsets = frequent_itemsets[frequent_itemsets['length'] >= 2].drop(columns='length')

    # Classement par ordre décroissant de support 
    frequent_itemsets = frequent_itemsets.sort_values(by='support', ascending=False)
    #print(frequent_itemsets)
    #print(frequent_itemsets['itemsets'].unique())
    
    # Recherche de règles d'association avec un lift supérieur à 1 
    rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1, support_only=True)
    
    # Affichage des règles d'association intéressantes
    if len(rules)>0: 
        print(insect, " : ", rules)
# Out:
# Callimus  :                  antecedents               consequents  antecedent support  \
# 0        (nebulosite_0-25%)  (insecte_genre_Callimus)                 NaN
# 1  (insecte_genre_Callimus)        (nebulosite_0-25%)                 NaN
#
#    consequent support  support  confidence  lift  leverage  conviction  \
# 0                 NaN      1.0         NaN   NaN       NaN         NaN
# 1                 NaN      1.0         NaN   NaN       NaN         NaN
#
#    zhangs_metric
# 0            NaN
# 1            NaN
# Toxophora  :                   antecedents                consequents  antecedent support  \
# 0  (insecte_genre_Toxophora)         (nebulosite_0-25%)                 NaN
# 1         (nebulosite_0-25%)  (insecte_genre_Toxophora)                 NaN
#
#    consequent support  support  confidence  lift  leverage  conviction  \
# 0                 NaN      1.0         NaN   NaN       NaN         NaN
# 1                 NaN      1.0         NaN   NaN       NaN         NaN
#
#    zhangs_metric
# 0            NaN
# 1            NaN
# Idaea  :               antecedents            consequents  antecedent support  \
# 0  (insecte_genre_Idaea)                (rural)                 NaN
# 1                (rural)  (insecte_genre_Idaea)                 NaN
#
#    consequent support  support  confidence  lift  leverage  conviction  \
# 0                 NaN      1.0         NaN   NaN       NaN         NaN
# 1                 NaN      1.0         NaN   NaN       NaN         NaN
#
#    zhangs_metric
# 0            NaN
# 1            NaN
# Lepturobosca  :                                              antecedents  \
# 0                                       (bord de l'eau)
# 1                                               (rural)
# 2                               (plante_genre_Bistorta)
# 3                                       (bord de l'eau)
# 4     (plante_genre_Bistorta, nebulosite_0-25%, vent...
# ...                                                 ...
# 1927                                    (bord de l'eau)
# 1928                                            (rural)
# 1929                             (vent_faible, continu)
# 1930                       (insecte_genre_Lepturobosca)
# 1931                              (temperature_10-20ºC)
#
#                                             consequents  antecedent support  \
# 0                                               (rural)                 NaN
# 1                                       (bord de l'eau)                 NaN
# 2                                       (bord de l'eau)                 NaN
# 3                               (plante_genre_Bistorta)                 NaN
# 4                          (insecte_genre_Lepturobosca)                 NaN
# ...                                                 ...                 ...
# 1927  (plante_genre_Bistorta, nebulosite_0-25%, rura...                 NaN
# 1928  (plante_genre_Bistorta, nebulosite_0-25%, bord...                 NaN
# 1929  (plante_genre_Bistorta, nebulosite_0-25%, bord...                 NaN
# 1930  (plante_genre_Bistorta, nebulosite_0-25%, bord...                 NaN
# 1931  (plante_genre_Bistorta, nebulosite_0-25%, bord...                 NaN
#
#       consequent support  support  confidence  lift  leverage  conviction  \
# 0                    NaN      1.0         NaN   NaN       NaN         NaN
# 1                    NaN      1.0         NaN   NaN       NaN         NaN
# 2                    NaN      1.0         NaN   NaN       NaN         NaN
# 3                    NaN      1.0         NaN   NaN       NaN         NaN
# 4                    NaN      1.0         NaN   NaN       NaN         NaN
# ...                  ...      ...         ...   ...       ...         ...
# 1927                 NaN      1.0         NaN   NaN       NaN         NaN
# 1928                 NaN      1.0         NaN   NaN       NaN         NaN
# 1929                 NaN      1.0         NaN   NaN       NaN         NaN
# 1930                 NaN      1.0         NaN   NaN       NaN         NaN
# 1931                 NaN      1.0         NaN   NaN       NaN         NaN
#
#       zhangs_metric
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 1927            NaN
# 1928            NaN
# 1929            NaN
# 1930            NaN
# 1931            NaN
#
# [1932 rows x 10 columns]
# Eupithecia  :                                          antecedents  \
# 0      (insecte_genre_Eupithecia, nebulosite_0-25%)
# 1   (insecte_genre_Eupithecia, temperature_20-30ºC)
# 2           (nebulosite_0-25%, temperature_20-30ºC)
# 3                        (insecte_genre_Eupithecia)
# 4                                (nebulosite_0-25%)
# 5                             (temperature_20-30ºC)
# 6                        (insecte_genre_Eupithecia)
# 7                                (nebulosite_0-25%)
# 8                                (nebulosite_0-25%)
# 9                             (temperature_20-30ºC)
# 10                       (insecte_genre_Eupithecia)
# 11                            (temperature_20-30ºC)
#
#                                         consequents  antecedent support  \
# 0                             (temperature_20-30ºC)                 NaN
# 1                                (nebulosite_0-25%)                 NaN
# 2                        (insecte_genre_Eupithecia)                 NaN
# 3           (nebulosite_0-25%, temperature_20-30ºC)                 NaN
# 4   (insecte_genre_Eupithecia, temperature_20-30ºC)                 NaN
# 5      (insecte_genre_Eupithecia, nebulosite_0-25%)                 NaN
# 6                                (nebulosite_0-25%)                 NaN
# 7                        (insecte_genre_Eupithecia)                 NaN
# 8                             (temperature_20-30ºC)                 NaN
# 9                                (nebulosite_0-25%)                 NaN
# 10                            (temperature_20-30ºC)                 NaN
# 11                       (insecte_genre_Eupithecia)                 NaN
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 0                  NaN      1.0         NaN   NaN       NaN         NaN
# 1                  NaN      1.0         NaN   NaN       NaN         NaN
# 2                  NaN      1.0         NaN   NaN       NaN         NaN
# 3                  NaN      1.0         NaN   NaN       NaN         NaN
# 4                  NaN      1.0         NaN   NaN       NaN         NaN
# 5                  NaN      1.0         NaN   NaN       NaN         NaN
# 6                  NaN      1.0         NaN   NaN       NaN         NaN
# 7                  NaN      1.0         NaN   NaN       NaN         NaN
# 8                  NaN      1.0         NaN   NaN       NaN         NaN
# 9                  NaN      1.0         NaN   NaN       NaN         NaN
# 10                 NaN      1.0         NaN   NaN       NaN         NaN
# 11                 NaN      1.0         NaN   NaN       NaN         NaN
#
#     zhangs_metric
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# Dascillus  :                   antecedents                consequents  antecedent support  \
# 0         (nebulosite_0-25%)  (insecte_genre_Dascillus)                 NaN
# 1  (insecte_genre_Dascillus)         (nebulosite_0-25%)                 NaN
#
#    consequent support  support  confidence  lift  leverage  conviction  \
# 0                 NaN      1.0         NaN   NaN       NaN         NaN
# 1                 NaN      1.0         NaN   NaN       NaN         NaN
#
#    zhangs_metric
# 0            NaN
# 1            NaN
# Ptinomorphus  :                                         antecedents  \
# 0   (insecte_genre_Ptinomorphus, nebulosite_0-25%)
# 1        (insecte_genre_Ptinomorphus, péri-urbain)
# 2                  (nebulosite_0-25%, péri-urbain)
# 3                     (insecte_genre_Ptinomorphus)
# 4                               (nebulosite_0-25%)
# 5                                    (péri-urbain)
# 6                               (nebulosite_0-25%)
# 7                                    (péri-urbain)
# 8                     (insecte_genre_Ptinomorphus)
# 9                                    (péri-urbain)
# 10                    (insecte_genre_Ptinomorphus)
# 11                              (nebulosite_0-25%)
#
#                                        consequents  antecedent support  \
# 0                                    (péri-urbain)                 NaN
# 1                               (nebulosite_0-25%)                 NaN
# 2                     (insecte_genre_Ptinomorphus)                 NaN
# 3                  (nebulosite_0-25%, péri-urbain)                 NaN
# 4        (insecte_genre_Ptinomorphus, péri-urbain)                 NaN
# 5   (insecte_genre_Ptinomorphus, nebulosite_0-25%)                 NaN
# 6                                    (péri-urbain)                 NaN
# 7                               (nebulosite_0-25%)                 NaN
# 8                                    (péri-urbain)                 NaN
# 9                     (insecte_genre_Ptinomorphus)                 NaN
# 10                              (nebulosite_0-25%)                 NaN
# 11                    (insecte_genre_Ptinomorphus)                 NaN
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 0                  NaN      1.0         NaN   NaN       NaN         NaN
# 1                  NaN      1.0         NaN   NaN       NaN         NaN
# 2                  NaN      1.0         NaN   NaN       NaN         NaN
# 3                  NaN      1.0         NaN   NaN       NaN         NaN
# 4                  NaN      1.0         NaN   NaN       NaN         NaN
# 5                  NaN      1.0         NaN   NaN       NaN         NaN
# 6                  NaN      1.0         NaN   NaN       NaN         NaN
# 7                  NaN      1.0         NaN   NaN       NaN         NaN
# 8                  NaN      1.0         NaN   NaN       NaN         NaN
# 9                  NaN      1.0         NaN   NaN       NaN         NaN
# 10                 NaN      1.0         NaN   NaN       NaN         NaN
# 11                 NaN      1.0         NaN   NaN       NaN         NaN
#
#     zhangs_metric
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# Scolitantides  :                       antecedents                    consequents  \
# 0                        (rural)  (insecte_genre_Scolitantides)
# 1  (insecte_genre_Scolitantides)                        (rural)
#
#    antecedent support  consequent support  support  confidence  lift  \
# 0                 NaN                 NaN      1.0         NaN   NaN
# 1                 NaN                 NaN      1.0         NaN   NaN
#
#    leverage  conviction  zhangs_metric
# 0       NaN         NaN            NaN
# 1       NaN         NaN            NaN
# Purpuricenus  :                      antecedents                   consequents  \
# 0            (nebulosite_0-25%)  (insecte_genre_Purpuricenus)
# 1  (insecte_genre_Purpuricenus)            (nebulosite_0-25%)
#
#    antecedent support  consequent support  support  confidence  lift  \
# 0                 NaN                 NaN      1.0         NaN   NaN
# 1                 NaN                 NaN      1.0         NaN   NaN
#
#    leverage  conviction  zhangs_metric
# 0       NaN         NaN            NaN
# 1       NaN         NaN            NaN
# Ptosima  :                 antecedents              consequents  antecedent support  \
# 0       (nebulosite_0-25%)  (insecte_genre_Ptosima)                 NaN
# 1  (insecte_genre_Ptosima)       (nebulosite_0-25%)                 NaN
#
#    consequent support  support  confidence  lift  leverage  conviction  \
# 0                 NaN      1.0         NaN   NaN       NaN         NaN
# 1                 NaN      1.0         NaN   NaN       NaN         NaN
#
#    zhangs_metric
# 0            NaN
# 1            NaN
# Cyrtus  :                antecedents             consequents  antecedent support  \
# 0  (insecte_genre_Cyrtus)      (nebulosite_0-25%)                 NaN
# 1      (nebulosite_0-25%)  (insecte_genre_Cyrtus)                 NaN
#
#    consequent support  support  confidence  lift  leverage  conviction  \
# 0                 NaN      1.0         NaN   NaN       NaN         NaN
# 1                 NaN      1.0         NaN   NaN       NaN         NaN
#
#    zhangs_metric
# 0            NaN
# 1            NaN
# Chorosoma  :                                            antecedents  \
# 0         (nebulosite_0-25%, insecte_genre_Chorosoma)
# 1                         (nebulosite_0-25%, prairie)
# 2                  (insecte_genre_Chorosoma, prairie)
# 3                                  (nebulosite_0-25%)
# 4                           (insecte_genre_Chorosoma)
# 5                                           (prairie)
# 6   (nebulosite_0-25%, temperature_20-30ºC, insect...
# 7    (nebulosite_0-25%, temperature_20-30ºC, prairie)
# 8   (nebulosite_0-25%, insecte_genre_Chorosoma, pr...
# 9   (temperature_20-30ºC, insecte_genre_Chorosoma,...
# 10            (nebulosite_0-25%, temperature_20-30ºC)
# 11        (nebulosite_0-25%, insecte_genre_Chorosoma)
# 12                        (nebulosite_0-25%, prairie)
# 13     (temperature_20-30ºC, insecte_genre_Chorosoma)
# 14                     (temperature_20-30ºC, prairie)
# 15                 (insecte_genre_Chorosoma, prairie)
# 16                                 (nebulosite_0-25%)
# 17                              (temperature_20-30ºC)
# 18                          (insecte_genre_Chorosoma)
# 19                                          (prairie)
# 20                              (temperature_20-30ºC)
# 21                          (insecte_genre_Chorosoma)
# 22                                 (nebulosite_0-25%)
# 23                                          (prairie)
# 24                              (temperature_20-30ºC)
# 25                                          (prairie)
# 26     (temperature_20-30ºC, insecte_genre_Chorosoma)
# 27                     (temperature_20-30ºC, prairie)
# 28                 (insecte_genre_Chorosoma, prairie)
# 29                              (temperature_20-30ºC)
# 30                          (insecte_genre_Chorosoma)
# 31                                          (prairie)
# 32                          (insecte_genre_Chorosoma)
# 33                                          (prairie)
# 34            (nebulosite_0-25%, temperature_20-30ºC)
# 35        (nebulosite_0-25%, insecte_genre_Chorosoma)
# 36     (temperature_20-30ºC, insecte_genre_Chorosoma)
# 37                                 (nebulosite_0-25%)
# 38                              (temperature_20-30ºC)
# 39                          (insecte_genre_Chorosoma)
# 40                                 (nebulosite_0-25%)
# 41                          (insecte_genre_Chorosoma)
# 42                                 (nebulosite_0-25%)
# 43                              (temperature_20-30ºC)
# 44            (nebulosite_0-25%, temperature_20-30ºC)
# 45                        (nebulosite_0-25%, prairie)
# 46                     (temperature_20-30ºC, prairie)
# 47                                 (nebulosite_0-25%)
# 48                              (temperature_20-30ºC)
# 49                                          (prairie)
#
#                                           consequents  antecedent support  \
# 0                                           (prairie)                 NaN
# 1                           (insecte_genre_Chorosoma)                 NaN
# 2                                  (nebulosite_0-25%)                 NaN
# 3                  (insecte_genre_Chorosoma, prairie)                 NaN
# 4                         (nebulosite_0-25%, prairie)                 NaN
# 5         (nebulosite_0-25%, insecte_genre_Chorosoma)                 NaN
# 6                                           (prairie)                 NaN
# 7                           (insecte_genre_Chorosoma)                 NaN
# 8                               (temperature_20-30ºC)                 NaN
# 9                                  (nebulosite_0-25%)                 NaN
# 10                 (insecte_genre_Chorosoma, prairie)                 NaN
# 11                     (temperature_20-30ºC, prairie)                 NaN
# 12     (temperature_20-30ºC, insecte_genre_Chorosoma)                 NaN
# 13                        (nebulosite_0-25%, prairie)                 NaN
# 14        (nebulosite_0-25%, insecte_genre_Chorosoma)                 NaN
# 15            (nebulosite_0-25%, temperature_20-30ºC)                 NaN
# 16  (temperature_20-30ºC, insecte_genre_Chorosoma,...                 NaN
# 17  (nebulosite_0-25%, insecte_genre_Chorosoma, pr...                 NaN
# 18   (nebulosite_0-25%, temperature_20-30ºC, prairie)                 NaN
# 19  (nebulosite_0-25%, temperature_20-30ºC, insect...                 NaN
# 20                          (insecte_genre_Chorosoma)                 NaN
# 21                              (temperature_20-30ºC)                 NaN
# 22                                          (prairie)                 NaN
# 23                                 (nebulosite_0-25%)                 NaN
# 24                                          (prairie)                 NaN
# 25                              (temperature_20-30ºC)                 NaN
# 26                                          (prairie)                 NaN
# 27                          (insecte_genre_Chorosoma)                 NaN
# 28                              (temperature_20-30ºC)                 NaN
# 29                 (insecte_genre_Chorosoma, prairie)                 NaN
# 30                     (temperature_20-30ºC, prairie)                 NaN
# 31     (temperature_20-30ºC, insecte_genre_Chorosoma)                 NaN
# 32                                          (prairie)                 NaN
# 33                          (insecte_genre_Chorosoma)                 NaN
# 34                          (insecte_genre_Chorosoma)                 NaN
# 35                              (temperature_20-30ºC)                 NaN
# 36                                 (nebulosite_0-25%)                 NaN
# 37     (temperature_20-30ºC, insecte_genre_Chorosoma)                 NaN
# 38        (nebulosite_0-25%, insecte_genre_Chorosoma)                 NaN
# 39            (nebulosite_0-25%, temperature_20-30ºC)                 NaN
# 40                          (insecte_genre_Chorosoma)                 NaN
# 41                                 (nebulosite_0-25%)                 NaN
# 42                              (temperature_20-30ºC)                 NaN
# 43                                 (nebulosite_0-25%)                 NaN
# 44                                          (prairie)                 NaN
# 45                              (temperature_20-30ºC)                 NaN
# 46                                 (nebulosite_0-25%)                 NaN
# 47                     (temperature_20-30ºC, prairie)                 NaN
# 48                        (nebulosite_0-25%, prairie)                 NaN
# 49            (nebulosite_0-25%, temperature_20-30ºC)                 NaN
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 0                  NaN      1.0         NaN   NaN       NaN         NaN
# 1                  NaN      1.0         NaN   NaN       NaN         NaN
# 2                  NaN      1.0         NaN   NaN       NaN         NaN
# 3                  NaN      1.0         NaN   NaN       NaN         NaN
# 4                  NaN      1.0         NaN   NaN       NaN         NaN
# 5                  NaN      1.0         NaN   NaN       NaN         NaN
# 6                  NaN      1.0         NaN   NaN       NaN         NaN
# 7                  NaN      1.0         NaN   NaN       NaN         NaN
# 8                  NaN      1.0         NaN   NaN       NaN         NaN
# 9                  NaN      1.0         NaN   NaN       NaN         NaN
# 10                 NaN      1.0         NaN   NaN       NaN         NaN
# 11                 NaN      1.0         NaN   NaN       NaN         NaN
# 12                 NaN      1.0         NaN   NaN       NaN         NaN
# 13                 NaN      1.0         NaN   NaN       NaN         NaN
# 14                 NaN      1.0         NaN   NaN       NaN         NaN
# 15                 NaN      1.0         NaN   NaN       NaN         NaN
# 16                 NaN      1.0         NaN   NaN       NaN         NaN
# 17                 NaN      1.0         NaN   NaN       NaN         NaN
# 18                 NaN      1.0         NaN   NaN       NaN         NaN
# 19                 NaN      1.0         NaN   NaN       NaN         NaN
# 20                 NaN      1.0         NaN   NaN       NaN         NaN
# 21                 NaN      1.0         NaN   NaN       NaN         NaN
# 22                 NaN      1.0         NaN   NaN       NaN         NaN
# 23                 NaN      1.0         NaN   NaN       NaN         NaN
# 24                 NaN      1.0         NaN   NaN       NaN         NaN
# 25                 NaN      1.0         NaN   NaN       NaN         NaN
# 26                 NaN      1.0         NaN   NaN       NaN         NaN
# 27                 NaN      1.0         NaN   NaN       NaN         NaN
# 28                 NaN      1.0         NaN   NaN       NaN         NaN
# 29                 NaN      1.0         NaN   NaN       NaN         NaN
# 30                 NaN      1.0         NaN   NaN       NaN         NaN
# 31                 NaN      1.0         NaN   NaN       NaN         NaN
# 32                 NaN      1.0         NaN   NaN       NaN         NaN
# 33                 NaN      1.0         NaN   NaN       NaN         NaN
# 34                 NaN      1.0         NaN   NaN       NaN         NaN
# 35                 NaN      1.0         NaN   NaN       NaN         NaN
# 36                 NaN      1.0         NaN   NaN       NaN         NaN
# 37                 NaN      1.0         NaN   NaN       NaN         NaN
# 38                 NaN      1.0         NaN   NaN       NaN         NaN
# 39                 NaN      1.0         NaN   NaN       NaN         NaN
# 40                 NaN      1.0         NaN   NaN       NaN         NaN
# 41                 NaN      1.0         NaN   NaN       NaN         NaN
# 42                 NaN      1.0         NaN   NaN       NaN         NaN
# 43                 NaN      1.0         NaN   NaN       NaN         NaN
# 44                 NaN      1.0         NaN   NaN       NaN         NaN
# 45                 NaN      1.0         NaN   NaN       NaN         NaN
# 46                 NaN      1.0         NaN   NaN       NaN         NaN
# 47                 NaN      1.0         NaN   NaN       NaN         NaN
# 48                 NaN      1.0         NaN   NaN       NaN         NaN
# 49                 NaN      1.0         NaN   NaN       NaN         NaN
#
#     zhangs_metric
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# 30            NaN
# 31            NaN
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# 36            NaN
# 37            NaN
# 38            NaN
# 39            NaN
# 40            NaN
# 41            NaN
# 42            NaN
# 43            NaN
# 44            NaN
# 45            NaN
# 46            NaN
# 47            NaN
# 48            NaN
# 49            NaN
# Lithosia  :                                            antecedents  \
# 0                                             (rural)
# 1                                      (jardin privé)
# 2                             (plante_genre_Buddleja)
# 3                                             (rural)
# 4                      (plante_genre_Buddleja, rural)
# 5               (plante_genre_Buddleja, jardin privé)
# 6                               (rural, jardin privé)
# 7                             (plante_genre_Buddleja)
# 8                                             (rural)
# 9                                      (jardin privé)
# 10    (plante_genre_Buddleja, insecte_genre_Lithosia)
# 11              (plante_genre_Buddleja, jardin privé)
# 12             (insecte_genre_Lithosia, jardin privé)
# 13                            (plante_genre_Buddleja)
# 14                           (insecte_genre_Lithosia)
# 15                                     (jardin privé)
# 16    (plante_genre_Buddleja, insecte_genre_Lithosia)
# 17                     (plante_genre_Buddleja, rural)
# 18                    (insecte_genre_Lithosia, rural)
# 19                            (plante_genre_Buddleja)
# 20                           (insecte_genre_Lithosia)
# 21                                            (rural)
# 22                            (plante_genre_Buddleja)
# 23                           (insecte_genre_Lithosia)
# 24  (plante_genre_Buddleja, insecte_genre_Lithosia...
# 25  (plante_genre_Buddleja, insecte_genre_Lithosia...
# 26       (plante_genre_Buddleja, rural, jardin privé)
# 27      (insecte_genre_Lithosia, rural, jardin privé)
# 28    (plante_genre_Buddleja, insecte_genre_Lithosia)
# 29                     (plante_genre_Buddleja, rural)
# 30              (plante_genre_Buddleja, jardin privé)
# 31                    (insecte_genre_Lithosia, rural)
# 32             (insecte_genre_Lithosia, jardin privé)
# 33                              (rural, jardin privé)
# 34                            (plante_genre_Buddleja)
# 35                           (insecte_genre_Lithosia)
# 36                                            (rural)
# 37                                     (jardin privé)
# 38                            (plante_genre_Buddleja)
# 39                                     (jardin privé)
# 40                           (insecte_genre_Lithosia)
# 41                                            (rural)
# 42                    (insecte_genre_Lithosia, rural)
# 43             (insecte_genre_Lithosia, jardin privé)
# 44                              (rural, jardin privé)
# 45                           (insecte_genre_Lithosia)
# 46                                            (rural)
# 47                                     (jardin privé)
# 48                           (insecte_genre_Lithosia)
# 49                                     (jardin privé)
#
#                                           consequents  antecedent support  \
# 0                                      (jardin privé)                 NaN
# 1                                             (rural)                 NaN
# 2                                             (rural)                 NaN
# 3                             (plante_genre_Buddleja)                 NaN
# 4                                      (jardin privé)                 NaN
# 5                                             (rural)                 NaN
# 6                             (plante_genre_Buddleja)                 NaN
# 7                               (rural, jardin privé)                 NaN
# 8               (plante_genre_Buddleja, jardin privé)                 NaN
# 9                      (plante_genre_Buddleja, rural)                 NaN
# 10                                     (jardin privé)                 NaN
# 11                           (insecte_genre_Lithosia)                 NaN
# 12                            (plante_genre_Buddleja)                 NaN
# 13             (insecte_genre_Lithosia, jardin privé)                 NaN
# 14              (plante_genre_Buddleja, jardin privé)                 NaN
# 15    (plante_genre_Buddleja, insecte_genre_Lithosia)                 NaN
# 16                                            (rural)                 NaN
# 17                           (insecte_genre_Lithosia)                 NaN
# 18                            (plante_genre_Buddleja)                 NaN
# 19                    (insecte_genre_Lithosia, rural)                 NaN
# 20                     (plante_genre_Buddleja, rural)                 NaN
# 21    (plante_genre_Buddleja, insecte_genre_Lithosia)                 NaN
# 22                           (insecte_genre_Lithosia)                 NaN
# 23                            (plante_genre_Buddleja)                 NaN
# 24                                     (jardin privé)                 NaN
# 25                                            (rural)                 NaN
# 26                           (insecte_genre_Lithosia)                 NaN
# 27                            (plante_genre_Buddleja)                 NaN
# 28                              (rural, jardin privé)                 NaN
# 29             (insecte_genre_Lithosia, jardin privé)                 NaN
# 30                    (insecte_genre_Lithosia, rural)                 NaN
# 31              (plante_genre_Buddleja, jardin privé)                 NaN
# 32                     (plante_genre_Buddleja, rural)                 NaN
# 33    (plante_genre_Buddleja, insecte_genre_Lithosia)                 NaN
# 34      (insecte_genre_Lithosia, rural, jardin privé)                 NaN
# 35       (plante_genre_Buddleja, rural, jardin privé)                 NaN
# 36  (plante_genre_Buddleja, insecte_genre_Lithosia...                 NaN
# 37  (plante_genre_Buddleja, insecte_genre_Lithosia...                 NaN
# 38                                     (jardin privé)                 NaN
# 39                            (plante_genre_Buddleja)                 NaN
# 40                                            (rural)                 NaN
# 41                           (insecte_genre_Lithosia)                 NaN
# 42                                     (jardin privé)                 NaN
# 43                                            (rural)                 NaN
# 44                           (insecte_genre_Lithosia)                 NaN
# 45                              (rural, jardin privé)                 NaN
# 46             (insecte_genre_Lithosia, jardin privé)                 NaN
# 47                    (insecte_genre_Lithosia, rural)                 NaN
# 48                                     (jardin privé)                 NaN
# 49                           (insecte_genre_Lithosia)                 NaN
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 0                  NaN      1.0         NaN   NaN       NaN         NaN
# 1                  NaN      1.0         NaN   NaN       NaN         NaN
# 2                  NaN      1.0         NaN   NaN       NaN         NaN
# 3                  NaN      1.0         NaN   NaN       NaN         NaN
# 4                  NaN      1.0         NaN   NaN       NaN         NaN
# 5                  NaN      1.0         NaN   NaN       NaN         NaN
# 6                  NaN      1.0         NaN   NaN       NaN         NaN
# 7                  NaN      1.0         NaN   NaN       NaN         NaN
# 8                  NaN      1.0         NaN   NaN       NaN         NaN
# 9                  NaN      1.0         NaN   NaN       NaN         NaN
# 10                 NaN      1.0         NaN   NaN       NaN         NaN
# 11                 NaN      1.0         NaN   NaN       NaN         NaN
# 12                 NaN      1.0         NaN   NaN       NaN         NaN
# 13                 NaN      1.0         NaN   NaN       NaN         NaN
# 14                 NaN      1.0         NaN   NaN       NaN         NaN
# 15                 NaN      1.0         NaN   NaN       NaN         NaN
# 16                 NaN      1.0         NaN   NaN       NaN         NaN
# 17                 NaN      1.0         NaN   NaN       NaN         NaN
# 18                 NaN      1.0         NaN   NaN       NaN         NaN
# 19                 NaN      1.0         NaN   NaN       NaN         NaN
# 20                 NaN      1.0         NaN   NaN       NaN         NaN
# 21                 NaN      1.0         NaN   NaN       NaN         NaN
# 22                 NaN      1.0         NaN   NaN       NaN         NaN
# 23                 NaN      1.0         NaN   NaN       NaN         NaN
# 24                 NaN      1.0         NaN   NaN       NaN         NaN
# 25                 NaN      1.0         NaN   NaN       NaN         NaN
# 26                 NaN      1.0         NaN   NaN       NaN         NaN
# 27                 NaN      1.0         NaN   NaN       NaN         NaN
# 28                 NaN      1.0         NaN   NaN       NaN         NaN
# 29                 NaN      1.0         NaN   NaN       NaN         NaN
# 30                 NaN      1.0         NaN   NaN       NaN         NaN
# 31                 NaN      1.0         NaN   NaN       NaN         NaN
# 32                 NaN      1.0         NaN   NaN       NaN         NaN
# 33                 NaN      1.0         NaN   NaN       NaN         NaN
# 34                 NaN      1.0         NaN   NaN       NaN         NaN
# 35                 NaN      1.0         NaN   NaN       NaN         NaN
# 36                 NaN      1.0         NaN   NaN       NaN         NaN
# 37                 NaN      1.0         NaN   NaN       NaN         NaN
# 38                 NaN      1.0         NaN   NaN       NaN         NaN
# 39                 NaN      1.0         NaN   NaN       NaN         NaN
# 40                 NaN      1.0         NaN   NaN       NaN         NaN
# 41                 NaN      1.0         NaN   NaN       NaN         NaN
# 42                 NaN      1.0         NaN   NaN       NaN         NaN
# 43                 NaN      1.0         NaN   NaN       NaN         NaN
# 44                 NaN      1.0         NaN   NaN       NaN         NaN
# 45                 NaN      1.0         NaN   NaN       NaN         NaN
# 46                 NaN      1.0         NaN   NaN       NaN         NaN
# 47                 NaN      1.0         NaN   NaN       NaN         NaN
# 48                 NaN      1.0         NaN   NaN       NaN         NaN
# 49                 NaN      1.0         NaN   NaN       NaN         NaN
#
#     zhangs_metric
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# 30            NaN
# 31            NaN
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# 36            NaN
# 37            NaN
# 38            NaN
# 39            NaN
# 40            NaN
# 41            NaN
# 42            NaN
# 43            NaN
# 44            NaN
# 45            NaN
# 46            NaN
# 47            NaN
# 48            NaN
# 49            NaN
# Angerona  :                                            antecedents  \
# 0                           (vent_faible, irrégulier)
# 1                                             (rural)
# 2         (vent_faible, irrégulier, nebulosite_0-25%)
# 3                    (vent_faible, irrégulier, rural)
# 4                           (nebulosite_0-25%, rural)
# 5                           (vent_faible, irrégulier)
# 6                                  (nebulosite_0-25%)
# 7                                             (rural)
# 8                            (insecte_genre_Angerona)
# 9                                  (nebulosite_0-25%)
# 10                          (vent_faible, irrégulier)
# 11                                 (nebulosite_0-25%)
# 12  (insecte_genre_Angerona, vent_faible, irrégulier)
# 13         (insecte_genre_Angerona, nebulosite_0-25%)
# 14        (vent_faible, irrégulier, nebulosite_0-25%)
# 15                           (insecte_genre_Angerona)
# 16                          (vent_faible, irrégulier)
# 17                                 (nebulosite_0-25%)
# 18  (insecte_genre_Angerona, vent_faible, irrégulier)
# 19                    (insecte_genre_Angerona, rural)
# 20                   (vent_faible, irrégulier, rural)
# 21                           (insecte_genre_Angerona)
# 22                          (vent_faible, irrégulier)
# 23                                            (rural)
# 24  (insecte_genre_Angerona, vent_faible, irréguli...
# 25  (insecte_genre_Angerona, vent_faible, irréguli...
# 26  (insecte_genre_Angerona, nebulosite_0-25%, rural)
# 27  (vent_faible, irrégulier, nebulosite_0-25%, ru...
# 28  (insecte_genre_Angerona, vent_faible, irrégulier)
# 29         (insecte_genre_Angerona, nebulosite_0-25%)
# 30                    (insecte_genre_Angerona, rural)
# 31        (vent_faible, irrégulier, nebulosite_0-25%)
# 32                   (vent_faible, irrégulier, rural)
# 33                          (nebulosite_0-25%, rural)
# 34                           (insecte_genre_Angerona)
# 35                          (vent_faible, irrégulier)
# 36                                 (nebulosite_0-25%)
# 37                                            (rural)
# 38                           (insecte_genre_Angerona)
# 39                                            (rural)
# 40         (insecte_genre_Angerona, nebulosite_0-25%)
# 41                    (insecte_genre_Angerona, rural)
# 42                          (nebulosite_0-25%, rural)
# 43                           (insecte_genre_Angerona)
# 44                                 (nebulosite_0-25%)
# 45                                            (rural)
# 46                                 (nebulosite_0-25%)
# 47                                            (rural)
# 48                           (insecte_genre_Angerona)
# 49                          (vent_faible, irrégulier)
#
#                                           consequents  antecedent support  \
# 0                                             (rural)                 NaN
# 1                           (vent_faible, irrégulier)                 NaN
# 2                                             (rural)                 NaN
# 3                                  (nebulosite_0-25%)                 NaN
# 4                           (vent_faible, irrégulier)                 NaN
# 5                           (nebulosite_0-25%, rural)                 NaN
# 6                    (vent_faible, irrégulier, rural)                 NaN
# 7         (vent_faible, irrégulier, nebulosite_0-25%)                 NaN
# 8                                  (nebulosite_0-25%)                 NaN
# 9                            (insecte_genre_Angerona)                 NaN
# 10                                 (nebulosite_0-25%)                 NaN
# 11                          (vent_faible, irrégulier)                 NaN
# 12                                 (nebulosite_0-25%)                 NaN
# 13                          (vent_faible, irrégulier)                 NaN
# 14                           (insecte_genre_Angerona)                 NaN
# 15        (vent_faible, irrégulier, nebulosite_0-25%)                 NaN
# 16         (insecte_genre_Angerona, nebulosite_0-25%)                 NaN
# 17  (insecte_genre_Angerona, vent_faible, irrégulier)                 NaN
# 18                                            (rural)                 NaN
# 19                          (vent_faible, irrégulier)                 NaN
# 20                           (insecte_genre_Angerona)                 NaN
# 21                   (vent_faible, irrégulier, rural)                 NaN
# 22                    (insecte_genre_Angerona, rural)                 NaN
# 23  (insecte_genre_Angerona, vent_faible, irrégulier)                 NaN
# 24                                            (rural)                 NaN
# 25                                 (nebulosite_0-25%)                 NaN
# 26                          (vent_faible, irrégulier)                 NaN
# 27                           (insecte_genre_Angerona)                 NaN
# 28                          (nebulosite_0-25%, rural)                 NaN
# 29                   (vent_faible, irrégulier, rural)                 NaN
# 30        (vent_faible, irrégulier, nebulosite_0-25%)                 NaN
# 31                    (insecte_genre_Angerona, rural)                 NaN
# 32         (insecte_genre_Angerona, nebulosite_0-25%)                 NaN
# 33  (insecte_genre_Angerona, vent_faible, irrégulier)                 NaN
# 34  (vent_faible, irrégulier, nebulosite_0-25%, ru...                 NaN
# 35  (insecte_genre_Angerona, nebulosite_0-25%, rural)                 NaN
# 36  (insecte_genre_Angerona, vent_faible, irréguli...                 NaN
# 37  (insecte_genre_Angerona, vent_faible, irréguli...                 NaN
# 38                                            (rural)                 NaN
# 39                           (insecte_genre_Angerona)                 NaN
# 40                                            (rural)                 NaN
# 41                                 (nebulosite_0-25%)                 NaN
# 42                           (insecte_genre_Angerona)                 NaN
# 43                          (nebulosite_0-25%, rural)                 NaN
# 44                    (insecte_genre_Angerona, rural)                 NaN
# 45         (insecte_genre_Angerona, nebulosite_0-25%)                 NaN
# 46                                            (rural)                 NaN
# 47                                 (nebulosite_0-25%)                 NaN
# 48                          (vent_faible, irrégulier)                 NaN
# 49                           (insecte_genre_Angerona)                 NaN
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 0                  NaN      1.0         NaN   NaN       NaN         NaN
# 1                  NaN      1.0         NaN   NaN       NaN         NaN
# 2                  NaN      1.0         NaN   NaN       NaN         NaN
# 3                  NaN      1.0         NaN   NaN       NaN         NaN
# 4                  NaN      1.0         NaN   NaN       NaN         NaN
# 5                  NaN      1.0         NaN   NaN       NaN         NaN
# 6                  NaN      1.0         NaN   NaN       NaN         NaN
# 7                  NaN      1.0         NaN   NaN       NaN         NaN
# 8                  NaN      1.0         NaN   NaN       NaN         NaN
# 9                  NaN      1.0         NaN   NaN       NaN         NaN
# 10                 NaN      1.0         NaN   NaN       NaN         NaN
# 11                 NaN      1.0         NaN   NaN       NaN         NaN
# 12                 NaN      1.0         NaN   NaN       NaN         NaN
# 13                 NaN      1.0         NaN   NaN       NaN         NaN
# 14                 NaN      1.0         NaN   NaN       NaN         NaN
# 15                 NaN      1.0         NaN   NaN       NaN         NaN
# 16                 NaN      1.0         NaN   NaN       NaN         NaN
# 17                 NaN      1.0         NaN   NaN       NaN         NaN
# 18                 NaN      1.0         NaN   NaN       NaN         NaN
# 19                 NaN      1.0         NaN   NaN       NaN         NaN
# 20                 NaN      1.0         NaN   NaN       NaN         NaN
# 21                 NaN      1.0         NaN   NaN       NaN         NaN
# 22                 NaN      1.0         NaN   NaN       NaN         NaN
# 23                 NaN      1.0         NaN   NaN       NaN         NaN
# 24                 NaN      1.0         NaN   NaN       NaN         NaN
# 25                 NaN      1.0         NaN   NaN       NaN         NaN
# 26                 NaN      1.0         NaN   NaN       NaN         NaN
# 27                 NaN      1.0         NaN   NaN       NaN         NaN
# 28                 NaN      1.0         NaN   NaN       NaN         NaN
# 29                 NaN      1.0         NaN   NaN       NaN         NaN
# 30                 NaN      1.0         NaN   NaN       NaN         NaN
# 31                 NaN      1.0         NaN   NaN       NaN         NaN
# 32                 NaN      1.0         NaN   NaN       NaN         NaN
# 33                 NaN      1.0         NaN   NaN       NaN         NaN
# 34                 NaN      1.0         NaN   NaN       NaN         NaN
# 35                 NaN      1.0         NaN   NaN       NaN         NaN
# 36                 NaN      1.0         NaN   NaN       NaN         NaN
# 37                 NaN      1.0         NaN   NaN       NaN         NaN
# 38                 NaN      1.0         NaN   NaN       NaN         NaN
# 39                 NaN      1.0         NaN   NaN       NaN         NaN
# 40                 NaN      1.0         NaN   NaN       NaN         NaN
# 41                 NaN      1.0         NaN   NaN       NaN         NaN
# 42                 NaN      1.0         NaN   NaN       NaN         NaN
# 43                 NaN      1.0         NaN   NaN       NaN         NaN
# 44                 NaN      1.0         NaN   NaN       NaN         NaN
# 45                 NaN      1.0         NaN   NaN       NaN         NaN
# 46                 NaN      1.0         NaN   NaN       NaN         NaN
# 47                 NaN      1.0         NaN   NaN       NaN         NaN
# 48                 NaN      1.0         NaN   NaN       NaN         NaN
# 49                 NaN      1.0         NaN   NaN       NaN         NaN
#
#     zhangs_metric
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# 30            NaN
# 31            NaN
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN
# 36            NaN
# 37            NaN
# 38            NaN
# 39            NaN
# 40            NaN
# 41            NaN
# 42            NaN
# 43            NaN
# 44            NaN
# 45            NaN
# ...
# 1                   NaN      1.0         NaN   NaN       NaN         NaN
# 2                   NaN      1.0         NaN   NaN       NaN         NaN
# 3                   NaN      1.0         NaN   NaN       NaN         NaN
# 4                   NaN      1.0         NaN   NaN       NaN         NaN
# ..                  ...      ...         ...   ...       ...         ...
# 597                 NaN      1.0         NaN   NaN       NaN         NaN
# 598                 NaN      1.0         NaN   NaN       NaN         NaN
# 599                 NaN      1.0         NaN   NaN       NaN         NaN
# 600                 NaN      1.0         NaN   NaN       NaN         NaN
# 601                 NaN      1.0         NaN   NaN       NaN         NaN
#
#      zhangs_metric
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 597            NaN
# 598            NaN
# 599            NaN
# 600            NaN
# 601            NaN
#
# [602 rows x 10 columns]
# Smerinthus  :                                              antecedents  \
# 0                                              (urbain)
# 1                                        (jardin privé)
# 2                                (plante_genre_Sinapis)
# 3                                        (jardin privé)
# 4     (plante_genre_Sinapis, nebulosite_50-75%, inse...
# ...                                                 ...
# 1927                                (nebulosite_50-75%)
# 1928                               (vent_fort, continu)
# 1929                         (insecte_genre_Smerinthus)
# 1930                             (plante_genre_Sinapis)
# 1931                                     (jardin privé)
#
#                                             consequents  antecedent support  \
# 0                                        (jardin privé)                 NaN
# 1                                              (urbain)                 NaN
# 2                                        (jardin privé)                 NaN
# 3                                (plante_genre_Sinapis)                 NaN
# 4                                  (vent_fort, continu)                 NaN
# ...                                                 ...                 ...
# 1927  (urbain, plante_genre_Sinapis, vent_fort, cont...                 NaN
# 1928  (urbain, nebulosite_50-75%, plante_genre_Sinap...                 NaN
# 1929  (urbain, nebulosite_50-75%, plante_genre_Sinap...                 NaN
# 1930  (urbain, nebulosite_50-75%, vent_fort, continu...                 NaN
# 1931  (urbain, nebulosite_50-75%, plante_genre_Sinap...                 NaN
#
#       consequent support  support  confidence  lift  leverage  conviction  \
# 0                    NaN      1.0         NaN   NaN       NaN         NaN
# 1                    NaN      1.0         NaN   NaN       NaN         NaN
# 2                    NaN      1.0         NaN   NaN       NaN         NaN
# 3                    NaN      1.0         NaN   NaN       NaN         NaN
# 4                    NaN      1.0         NaN   NaN       NaN         NaN
# ...                  ...      ...         ...   ...       ...         ...
# 1927                 NaN      1.0         NaN   NaN       NaN         NaN
# 1928                 NaN      1.0         NaN   NaN       NaN         NaN
# 1929                 NaN      1.0         NaN   NaN       NaN         NaN
# 1930                 NaN      1.0         NaN   NaN       NaN         NaN
# 1931                 NaN      1.0         NaN   NaN       NaN         NaN
#
#       zhangs_metric
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 1927            NaN
# 1928            NaN
# 1929            NaN
# 1930            NaN
# 1931            NaN
#
# [1932 rows x 10 columns]
# Hyles  :                                              antecedents  \
# 0                                               (rural)
# 1                                             (prairie)
# 2                              (plante_genre_Saponaria)
# 3                                             (prairie)
# 4     (nebulosite_75-100%, plante_genre_Saponaria, v...
# ...                                                 ...
# 1927                                         (vent_nul)
# 1928                           (plante_genre_Saponaria)
# 1929                              (insecte_genre_Hyles)
# 1930                                          (prairie)
# 1931                               (nebulosite_75-100%)
#
#                                             consequents  antecedent support  \
# 0                                             (prairie)                 NaN
# 1                                               (rural)                 NaN
# 2                                             (prairie)                 NaN
# 3                              (plante_genre_Saponaria)                 NaN
# 4                                 (insecte_genre_Hyles)                 NaN
# ...                                                 ...                 ...
# 1927  (nebulosite_75-100%, rural, plante_genre_Sapon...                 NaN
# 1928  (nebulosite_75-100%, rural, vent_nul, insecte_...                 NaN
# 1929  (nebulosite_75-100%, rural, vent_nul, plante_g...                 NaN
# 1930  (nebulosite_75-100%, rural, vent_nul, plante_g...                 NaN
# 1931  (rural, vent_nul, plante_genre_Saponaria, inse...                 NaN
#
#       consequent support  support  confidence  lift  leverage  conviction  \
# 0                    NaN      1.0         NaN   NaN       NaN         NaN
# 1                    NaN      1.0         NaN   NaN       NaN         NaN
# 2                    NaN      1.0         NaN   NaN       NaN         NaN
# 3                    NaN      1.0         NaN   NaN       NaN         NaN
# 4                    NaN      1.0         NaN   NaN       NaN         NaN
# ...                  ...      ...         ...   ...       ...         ...
# 1927                 NaN      1.0         NaN   NaN       NaN         NaN
# 1928                 NaN      1.0         NaN   NaN       NaN         NaN
# 1929                 NaN      1.0         NaN   NaN       NaN         NaN
# 1930                 NaN      1.0         NaN   NaN       NaN         NaN
# 1931                 NaN      1.0         NaN   NaN       NaN         NaN
#
#       zhangs_metric
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 1927            NaN
# 1928            NaN
# 1929            NaN
# 1930            NaN
# 1931            NaN
#
# [1932 rows x 10 columns]
# Anarta  :                antecedents             consequents  antecedent support  \
# 0                 (rural)  (insecte_genre_Anarta)                 NaN
# 1  (insecte_genre_Anarta)                 (rural)                 NaN
#
#    consequent support  support  confidence  lift  leverage  conviction  \
# 0                 NaN      1.0         NaN   NaN       NaN         NaN
# 1                 NaN      1.0         NaN   NaN       NaN         NaN
#
#    zhangs_metric
# 0            NaN
# 1            NaN
# Dasyscolia  :                                              antecedents  \
# 0                                               (rural)
# 1                                        (jardin privé)
# 2                               (plante_genre_Echinops)
# 3                                        (jardin privé)
# 4     (vent_faible, irrégulier, insecte_genre_Dasysc...
# ...                                                 ...
# 1927                                (nebulosite_50-75%)
# 1928                              (temperature_20-30ºC)
# 1929                          (vent_faible, irrégulier)
# 1930                         (insecte_genre_Dasyscolia)
# 1931                                     (jardin privé)
#
#                                             consequents  antecedent support  \
# 0                                        (jardin privé)                 NaN
# 1                                               (rural)                 NaN
# 2                                        (jardin privé)                 NaN
# 3                               (plante_genre_Echinops)                 NaN
# 4                               (plante_genre_Echinops)                 NaN
# ...                                                 ...                 ...
# 1927  (plante_genre_Echinops, rural, temperature_20-...                 NaN
# 1928  (plante_genre_Echinops, rural, nebulosite_50-7...                 NaN
# 1929  (plante_genre_Echinops, rural, nebulosite_50-7...                 NaN
# 1930  (plante_genre_Echinops, rural, nebulosite_50-7...                 NaN
# 1931  (plante_genre_Echinops, rural, nebulosite_50-7...                 NaN
#
#       consequent support  support  confidence  lift  leverage  conviction  \
# 0                    NaN      1.0         NaN   NaN       NaN         NaN
# 1                    NaN      1.0         NaN   NaN       NaN         NaN
# 2                    NaN      1.0         NaN   NaN       NaN         NaN
# 3                    NaN      1.0         NaN   NaN       NaN         NaN
# 4                    NaN      1.0         NaN   NaN       NaN         NaN
# ...                  ...      ...         ...   ...       ...         ...
# 1927                 NaN      1.0         NaN   NaN       NaN         NaN
# 1928                 NaN      1.0         NaN   NaN       NaN         NaN
# 1929                 NaN      1.0         NaN   NaN       NaN         NaN
# 1930                 NaN      1.0         NaN   NaN       NaN         NaN
# 1931                 NaN      1.0         NaN   NaN       NaN         NaN
#
#       zhangs_metric
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 1927            NaN
# 1928            NaN
# 1929            NaN
# 1930            NaN
# 1931            NaN
#
# [1932 rows x 10 columns]
# Proserpinus  :                                              antecedents  \
# 0                                               (rural)
# 1                                        (jardin privé)
# 2                              (plante_genre_Lavandula)
# 3                                        (jardin privé)
# 4     (insecte_genre_Proserpinus, vent_faible, irrég...
# ...                                                 ...
# 1927                              (temperature_20-30ºC)
# 1928                           (plante_genre_Lavandula)
# 1929                        (insecte_genre_Proserpinus)
# 1930                          (vent_faible, irrégulier)
# 1931                                     (jardin privé)
#
#                                             consequents  antecedent support  \
# 0                                        (jardin privé)                 NaN
# 1                                               (rural)                 NaN
# 2                                        (jardin privé)                 NaN
# 3                              (plante_genre_Lavandula)                 NaN
# 4                              (plante_genre_Lavandula)                 NaN
# ...                                                 ...                 ...
# 1927  (nebulosite_0-25%, rural, plante_genre_Lavandu...                 NaN
# 1928  (nebulosite_0-25%, rural, temperature_20-30ºC,...                 NaN
# 1929  (nebulosite_0-25%, rural, temperature_20-30ºC,...                 NaN
# 1930  (nebulosite_0-25%, rural, temperature_20-30ºC,...                 NaN
# 1931  (nebulosite_0-25%, rural, temperature_20-30ºC,...                 NaN
#
#       consequent support  support  confidence  lift  leverage  conviction  \
# 0                    NaN      1.0         NaN   NaN       NaN         NaN
# 1                    NaN      1.0         NaN   NaN       NaN         NaN
# 2                    NaN      1.0         NaN   NaN       NaN         NaN
# 3                    NaN      1.0         NaN   NaN       NaN         NaN
# 4                    NaN      1.0         NaN   NaN       NaN         NaN
# ...                  ...      ...         ...   ...       ...         ...
# 1927                 NaN      1.0         NaN   NaN       NaN         NaN
# 1928                 NaN      1.0         NaN   NaN       NaN         NaN
# 1929                 NaN      1.0         NaN   NaN       NaN         NaN
# 1930                 NaN      1.0         NaN   NaN       NaN         NaN
# 1931                 NaN      1.0         NaN   NaN       NaN         NaN
#
#       zhangs_metric
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 1927            NaN
# 1928            NaN
# 1929            NaN
# 1930            NaN
# 1931            NaN
#
# [1932 rows x 10 columns]
# Pseudoips  :                                              antecedents  \
# 0                                               (forêt)
# 1                                               (rural)
# 2                                (plante_genre_Cirsium)
# 3                                               (forêt)
# 4     (nebulosite_75-100%, vent_faible, irrégulier, ...
# ...                                                 ...
# 1927                              (temperature_20-30ºC)
# 1928                          (insecte_genre_Pseudoips)
# 1929                               (nebulosite_75-100%)
# 1930                          (vent_faible, irrégulier)
# 1931                             (plante_genre_Cirsium)
#
#                                             consequents  antecedent support  \
# 0                                               (rural)                 NaN
# 1                                               (forêt)                 NaN
# 2                                               (forêt)                 NaN
# 3                                (plante_genre_Cirsium)                 NaN
# 4                             (insecte_genre_Pseudoips)                 NaN
# ...                                                 ...                 ...
# 1927  (plante_genre_Cirsium, rural, insecte_genre_Ps...                 NaN
# 1928  (plante_genre_Cirsium, rural, temperature_20-3...                 NaN
# 1929  (plante_genre_Cirsium, rural, temperature_20-3...                 NaN
# 1930  (plante_genre_Cirsium, rural, temperature_20-3...                 NaN
# 1931  (rural, temperature_20-30ºC, insecte_genre_Pse...                 NaN
#
#       consequent support  support  confidence  lift  leverage  conviction  \
# 0                    NaN      1.0         NaN   NaN       NaN         NaN
# 1                    NaN      1.0         NaN   NaN       NaN         NaN
# 2                    NaN      1.0         NaN   NaN       NaN         NaN
# 3                    NaN      1.0         NaN   NaN       NaN         NaN
# 4                    NaN      1.0         NaN   NaN       NaN         NaN
# ...                  ...      ...         ...   ...       ...         ...
# 1927                 NaN      1.0         NaN   NaN       NaN         NaN
# 1928                 NaN      1.0         NaN   NaN       NaN         NaN
# 1929                 NaN      1.0         NaN   NaN       NaN         NaN
# 1930                 NaN      1.0         NaN   NaN       NaN         NaN
# 1931                 NaN      1.0         NaN   NaN       NaN         NaN
#
#       zhangs_metric
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 1927            NaN
# 1928            NaN
# 1929            NaN
# 1930            NaN
# 1931            NaN
#
# [1932 rows x 10 columns]

# %% [markdown]
# Quelques règles d'associations importantes trouvées :
# - Lepturobosca  - plante_genre_Bistorta
# - Lithosia  - plante_genre_Buddleja
# - Amata   - plante_genre_Heracleum
# - Danaus   - plante_genre_Buddleja
# - Nudaria  - plante_genre_Galactites
# - Setina  - plante_genre_Gentianella
# - Deilephila  - plante_genre_Buddleja
# - Laspeyria   - plante_genre_Calendula

# %% [markdown]
# ## Interprétation

# %%
# Nombre d'observations des insectes en question qui sont dans une règle d'association importante
print(len(df.where(df['insecte_genre']=='Lepturobosca').dropna(subset=['insecte_genre'])))
print(len(df.where(df['insecte_genre']=='Lithosia').dropna(subset=['insecte_genre'])))
print(len(df.where(df['insecte_genre']=='Amata').dropna(subset=['insecte_genre'])))
print(len(df.where(df['insecte_genre']=='Danaus').dropna(subset=['insecte_genre'])))
print(len(df.where(df['insecte_genre']=='Nudaria').dropna(subset=['insecte_genre'])))
print(len(df.where(df['insecte_genre']=='Setina').dropna(subset=['insecte_genre'])))
print(len(df.where(df['insecte_genre']=='Deilephila').dropna(subset=['insecte_genre'])))
print(len(df.where(df['insecte_genre']=='Laspeyria').dropna(subset=['insecte_genre'])))
# Out:
# 1
# 3
# 1
# 1
# 1
# 1
# 4
# 1

# %% [markdown]
# Ce sont des règles associations importantes car le support du motif fréquent est en fait égal à 1 et il n'y a pas d'autres observations venant infirmer la règle.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Pas de conclusion biologique pertinente. Règle d'association considérée comme importante dû à un nombre d'observations très faibles (inférieur à 5) pour les insectes en question.
# On n'approfondira pas davantage une recherche large sur toute la base de données à différents niveaux de taxonomies.
